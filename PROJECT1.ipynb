# %% [markdown]
# ## Image to Pencil Sketch Converter 🎨

# %%
pip install opencv-python
# Out:
# ...
#   Using cached opencv_python-4.12.0.88-cp37-abi3-macosx_13_0_arm64.whl.metadata (19 kB)
# ...
# Using cached opencv_python-4.12.0.88-cp37-abi3-macosx_13_0_arm64.whl (37.9 MB)
# ...
#
# [notice] A new release of pip is available: 24.3.1 -> 25.2
# [notice] To update, run: pip3 install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install opencv-contrib-python
# Out:
# ...
#   Using cached opencv_contrib_python-4.12.0.88-cp37-abi3-macosx_13_0_arm64.whl.metadata (19 kB)
# ...
# Using cached opencv_contrib_python-4.12.0.88-cp37-abi3-macosx_13_0_arm64.whl (46.9 MB)
# ...
#
# [notice] A new release of pip is available: 24.3.1 -> 25.2
# [notice] To update, run: pip3 install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
import cv2
print(cv2.__version__)
# Out:
# 4.12.0

# %%
# IMPORT LIBRARY

import cv2
import matplotlib.pyplot as plt

# %%
# Step 1: Read the image

img = cv2.imread("ChatGPT Image Aug 15, 2025 at 02_31_12 PM.png")  # Replace with your image path
# Out:
# [ WARN:0@0.523] global loadsave.cpp:275 findDecoder imread_('ChatGPT Image Aug 15, 2025 at 02_31_12 PM.png'): can't open/read file: check file path/integrity

# %%
# Step 2: Convert to grayscale

gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# Cell In[6], line 3
#       1 # Step 2: Convert to grayscale
# ----> 3 gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
#
# error: OpenCV(4.12.0) /Users/xperience/GHA-Actions-OpenCV/_work/opencv-python/opencv-python/opencv/modules/imgproc/src/color.cpp:199: error: (-215:Assertion failed) !_src.empty() in function 'cvtColor'

# %%
# Step 3: Invert grayscale

inv_gray = 255 - gray

# %%
# Step 4: Apply Gaussian Blur

blur = cv2.GaussianBlur(inv_gray, (21, 21), 0)

# %%
# Step 5: Dodge blend the grayscale with the blurred inverted image

sketch = cv2.divide(gray, 255 - blur, scale=256)

# %%
# Display results

plt.figure(figsize=(10,5))
plt.subplot(1,2,1)
plt.imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB))
plt.title("Original Image")
plt.axis('off')

plt.subplot(1,2,2)
plt.imshow(sketch, cmap='gray')
plt.title("Pencil Sketch")
plt.axis('off')
plt.show()
